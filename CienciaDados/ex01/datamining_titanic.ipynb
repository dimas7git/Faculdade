# %%
import pandas as pd

# %%
titanic =pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanicDF = pd.DataFrame(titanic['Age'])
titanicDF
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
titanicDF['Tarifa']= titanic['Fare']
titanicDF
# Out:
#       Age   Tarifa
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
titanicDF = titanicDF.dropna()
titanicDF
# Out:
#       Age   Tarifa
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 885  39.0  29.1250
# 886  27.0  13.0000
# 887  19.0  30.0000
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [714 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(titanicDF['Age'].values, titanicDF['Tarifa'].values)

# %%
plt.plot(titanicDF['Age'].values, titanicDF['Tarifa'].values, linewidth = 0, marker = '.', markersize = 10, mfc='pink')

# %%
plt.plot(titanicDF['Age'].values, titanicDF['Tarifa'].values, linewidth = 0, marker = '.', markersize = 10, mfc='pink', mec='black')
plt.xlabel('Idade')
plt.ylabel('Valor da Passagem')
plt.show()

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 25.4 MB/s eta 0:00:00m eta 0:00:01:01:01
# Requirement already satisfied: scipy>=1.5.0 in /usr/lib/python3/dist-packages (from scikit-learn) (1.8.0)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy>=1.17.3 in /usr/lib/python3/dist-packages (from scikit-learn) (1.21.5)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 KB 46.8 MB/s eta 0:00:00
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.0 threadpoolctl-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import linear_model

# %%
metodoRegressao = linear_model.LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(titanicDF.values[:,0], titanicDF.values[:,1], test_size=0.3)

# %%
metodoRegressao.fit(x_train.reshape(-1,1), y_train.reshape(-1,1))
# Out:
# LinearRegression()

# %%
print('Coeficiente Angular da reta', metodoRegressao.coef_)
print('Coeficiente Linear da reta', metodoRegressao.intercept_)
# Out:
# Coeficiente Angular da reta [[0.33950471]]
# Coeficiente Linear da reta [26.36170165]

# %%
plt.plot(titanicDF['Age'].values, titanicDF['Tarifa'].values, linewidth = 0, marker = '.', markersize = 10, mfc='pink', mec='black')
plt.plot(x_train, metodoRegressao.coef_[0][0]*x_train + metodoRegressao.intercept_[0], '-b')
plt.xlabel('Idade')
plt.ylabel('Valor da Passagem')
# Out:
# Text(0, 0.5, 'Valor da Passagem')

# %%
y_testPred = metodoRegressao.predict(x_test.reshape(-1,1))
import numpy as np

# %%
MSE = np.mean(np.square(y_testPred - y_test))
print('Erro quadrático médio: ', MSE)
# Out:
# Erro quadrático médio:  1427.1775720966748

# %%
MSE = np.mean(np.absolute(y_testPred - y_test))
print('Erro médio absoluto: ', MSE)
# Out:
# Erro médio absoluto:  28.231524827396324
